# %%
import pandas as pd
from tqdm import tqdm
import os
import numpy as np
import matplotlib.pyplot as plt

import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import yfinance as yf
import requests

# %%
path = '/Users/matthesfogtmann/Downloads/SEC data/'

# %% [markdown]
# # importing and restructuring all the finance data

# %%
def getDir(path):
    lst = []
    for i in os.listdir(path):
        if len(i)==6 and "q" in i:
            lst.append(i)
    return lst

def getFinacialData(filename=path+'/2022q4'):
    data = {i:pd.read_csv(f"{filename}{i}.txt",sep="\t") for i in ["tag","num","pre","sub"]}
    
    #drop things
    data["tag"].drop(columns=["version","custom","abstract","datatype","iord","crdr"],inplace=True)
    data["num"].drop(columns=["footnote"],inplace=True)
    data["pre"].drop(columns=["version","negating"],inplace=True)
    data["sub"].drop(columns=['stprba', 'zipba',
       'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
       'mas1', 'mas2', 'ein'],inplace=True)
    
    #make mapper for company names
    
    def mapper(colname):
        return {i:j for i,j in zip(data["sub"]["adsh"],data["sub"][colname])}
    
    def inverseMapper(colname):
        return {j:i for i,j in zip(data["sub"]["adsh"],data["sub"][colname])}
    
    data["num"]["name"] = data["num"]["adsh"].map(mapper("name"))
    data["pre"]["name"] = data["pre"]["adsh"].map(mapper("name"))
    
    data["num"].drop(columns=["version","coreg","adsh"],inplace=True)
    data["pre"].drop(columns=["adsh","plabel","inpth","rfile"],inplace=True)
    
    
    #get some sampels of company
    names = sorted(list(data["num"]["name"].unique()))[:3]
    stmts = data["pre"]["stmt"].unique()
    
    print(names)
    def f(data, names):
        dic = dict()
        for name in tqdm(names):
            #get dfs where name is equal to name
            df = data["num"][data["num"]["name"]==name].copy()
            df_stmt = data["pre"][data["pre"]["name"]==name]
            
            #creat of company dic to load finacial data onto
            dic[name] = dict()
            
            # creat stmts for each company
            for stmt in stmts:
                dic[name][stmt] = dict()
                
            # fill more data
            
            for tag in set(df["tag"]):
                df_stmt_temp = df_stmt[df_stmt["tag"]==tag]
                for stmt in set(df_stmt_temp["stmt"]):
                    df_temp = df[df["tag"]==tag]
                    df_temp = df_temp[df_temp["ddate"]==max(df_temp["ddate"])]
                    dic[name][stmt][list(df_temp["tag"])[0]]=df_temp["value"].values[0]
            
               
        return dic
    return f(data, names)


def combineReports(reports):
    reformed_dic = {}

    for report, level1 in reports.items():
        for company,level2 in level1.items():
            for stmt, level3 in level2.items():
                for tag, value in level3.items():
                    reformed_dic[(company,stmt,tag)] = {report:value}
                    
    return pd.DataFrame(reformed_dic)


def getTicker(company_name):
    
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

@np.vectorize
def timeString2float(x="2020q2"):
    lst = x.split("q")
    return int(lst[0])+(int(lst[1])-1)*0.25

# %%
reports = {i : getFinacialData(path+i+"/") for i in getDir(path)}
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['1 800 FLOWERS COM INC', '10X CAPITAL VENTURE ACQUISITION CORP. II', '10X CAPITAL VENTURE ACQUISITION CORP. III']
# 100%|██████████| 3/3 [00:00<00:00,  4.51it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['1 800 FLOWERS COM INC', '10X CAPITAL VENTURE ACQUISITION CORP. II', '10X CAPITAL VENTURE ACQUISITION CORP. III']
# 100%|██████████| 3/3 [00:00<00:00,  4.61it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['1 800 FLOWERS COM INC', '10X CAPITAL VENTURE ACQUISITION CORP. II', '10X CAPITAL VENTURE ACQUISITION CORP. III']
# 100%|██████████| 3/3 [00:00<00:00,  4.54it/s]
# <ipython-input-174-154d8f624564>:9: DtypeWarning:
#
# Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['1 800 FLOWERS COM INC', '10X CAPITAL VENTURE ACQUISITION CORP. II', '10X GENOMICS, INC.']
# 100%|██████████| 3/3 [00:00<00:00,  3.93it/s]

# %%
combineReports(reports)
# Out:
#          1 800 FLOWERS COM INC                             \
#                             BS
#        AdditionalPaidInCapital OtherLiabilitiesNoncurrent
# 2022q1             377234000.0                 22112000.0
# 2022q3                     NaN                        NaN
# 2022q2                     NaN                        NaN
#
#                                                                     \
#
#        OperatingLeaseLiabilityNoncurrent AccruedLiabilitiesCurrent
# 2022q1                       128620000.0               279345000.0
# 2022q3                               NaN                       NaN
# 2022q2                               NaN                       NaN
#
#                                                                   \
#
#        PreferredStockSharesIssued PreferredStockSharesAuthorized
# 2022q1                        0.0                     10000000.0
# 2022q3                        NaN                            NaN
# 2022q2                        NaN                            NaN
#
#                                                             \
#
#        DeferredIncomeTaxLiabilitiesNet LongTermDebtCurrent
# 2022q1                      32856000.0          20000000.0
# 2022q3                             NaN                 NaN
# 2022q2                             NaN                 NaN
#
#                                                \
#
#        PreferredStockParOrStatedValuePerShare
# 2022q1                                   0.01
# 2022q3                                    NaN
# 2022q2                                    NaN
#
#                                               ...  \
#                                               ...
#        CashAndCashEquivalentsAtCarryingValue  ...
# 2022q1                           271068000.0  ...
# 2022q3                                   NaN  ...
# 2022q2                                   NaN  ...
#
#                  10X GENOMICS, INC.               \
#                                  BS
#        PropertyPlantAndEquipmentNet InventoryNet
# 2022q1                  169492000.0   59966000.0
# 2022q3                          NaN          NaN
# 2022q2                          NaN          NaN
#
#                                                               \
#
#        RetainedEarningsAccumulatedDeficit LiabilitiesCurrent
# 2022q1                       -863321000.0        110357000.0
# 2022q3                                NaN                NaN
# 2022q2                                NaN                NaN
#
#                                                                                \
#
#        AdditionalPaidInCapitalCommonStock PrepaidExpenseAndOtherAssetsCurrent
# 2022q1                       1.680865e+09                          13896000.0
# 2022q3                                NaN                                 NaN
# 2022q2                                NaN                                 NaN
#
#                                                               \
#
#        EmployeeRelatedLiabilitiesCurrent PreferredStockValue
# 2022q1                        31626000.0                 0.0
# 2022q3                               NaN                 NaN
# 2022q2                               NaN                 NaN
#
#
#                                                    CP
#        LicenseFeesAccruedNoncurrent EntityPublicFloat
# 2022q1                    5814000.0      1.870000e+10
# 2022q3                          NaN               NaN
# 2022q2                          NaN               NaN
#
# [3 rows x 326 columns]

# %% [markdown]
# # company data

# %%
filename=path+'2022q4/'

data = {i:pd.read_csv(f"{filename}{i}.txt",sep="\t") for i in ["sub"]}

#drop things
data["sub"].drop(columns=['stprba', 'zipba', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
                          'mas1', 'mas2', 'ein'],inplace=True)

# %%
data = {i:pd.read_csv(f"{filename}{i}.txt",sep="\t") for i in ["tag","num","pre","sub"]}

# %%
data["sub"]
# Out:
#                        adsh      cik                            name     sic  \
# 0      0000014707-22-000072    14707                     CALERES INC  3140.0
# 1      0000014846-22-000059    14846            BRT APARTMENTS CORP.  6798.0
# 2      0000018349-22-000191    18349          SYNOVUS FINANCIAL CORP  6021.0
# 3      0000035527-22-000248    35527             FIFTH THIRD BANCORP  6022.0
# 4      0000041719-22-000063    41719                 GLATFELTER CORP  2621.0
# ...                     ...      ...                             ...     ...
# 23938  0001851734-22-000581  1386570                 CHROMADEX CORP.  2833.0
# 23939  0001852117-22-000371  1852117  ROCKLEY PHOTONICS HOLDINGS LTD  3674.0
# 23940  0001854270-22-000033  1854270         SENTI BIOSCIENCES, INC.  2836.0
# 23941  0001867096-22-000111  1867096  XERIS BIOPHARMA HOLDINGS, INC.  2834.0
# 23942  0001874178-22-000053  1874178    RIVIAN AUTOMOTIVE, INC. / DE  3711.0
#
#       countryba               cityba                               bas1  \
# 0            US             ST LOUIS                  8300 MARYLAND AVE
# 1            US           GREAT NECK                  60 CUTTER MILL RD
# 2            US             COLUMBUS                    1111 BAY AVENUE
# 3            US           CINCINNATI                 38 FOUNTAIN SQ PLZ
# 4            US            CHARLOTTE               4350 CONGRESS STREET
# ...         ...                  ...                                ...
# 23938        US          LOS ANGELES                10900 WILSHIRE BLVD
# 23939        KY          GEORGE TOWN           HARBOUR PLACE, 2ND FLOOR
# 23940        US  SOUTH SAN FRANCISCO     2 CORPORATE DRIVE, FIRST FLOOR
# 23941        US              CHICAGO  180 N. LASALLE STREET, SUITE 1600
# 23942        US               IRVINE                  14600 MYFORD ROAD
#
#       countryinc stprinc                   former  ...      period      fy  \
# 0             US      NY        BROWN SHOE CO INC  ...  20221031.0  2022.0
# 1             US      NY         BRT REALTY TRUST  ...  20221130.0     NaN
# 2             US      GA      CB&T BANCSHARES INC  ...  20221130.0     NaN
# 3             US      OH                      NaN  ...  20221130.0     NaN
# 4             US      PA        GLATFELTER P H CO  ...  20221130.0     NaN
# ...          ...     ...                      ...  ...         ...     ...
# 23938         US      DE     CODY RESOURCES, INC.  ...  20220930.0     NaN
# 23939         KY     NaN                      NaN  ...  20220930.0     NaN
# 23940         US      DE  SENTI BIOSCIENCES, INC.  ...  20220930.0     NaN
# 23941         US      DE                      NaN  ...  20220930.0     NaN
# 23942         US      DE                      NaN  ...  20220930.0     NaN
#
#         fp     filed               accepted  prevrpt  detail  \
# 0       Q3  20221206  2022-12-06 14:50:00.0        0       1
# 1      NaN  20221206  2022-12-06 16:16:00.0        0       0
# 2      NaN  20221206  2022-12-06 16:16:00.0        0       0
# 3      NaN  20221206  2022-12-06 17:01:00.0        0       0
# 4      NaN  20221206  2022-12-06 16:47:00.0        0       0
# ...    ...       ...                    ...      ...     ...
# 23938  NaN  20221003  2022-10-03 06:43:00.0        0       0
# 23939  NaN  20221003  2022-10-03 16:58:00.0        0       0
# 23940  NaN  20221003  2022-09-30 21:59:00.0        0       0
# 23941  NaN  20221003  2022-10-03 16:03:00.0        0       0
# 23942  NaN  20221003  2022-10-03 16:35:00.0        0       0
#
#                        instance  nciks aciks
# 0      cal-20221029x10q_htm.xml      1   NaN
# 1          brt-20221206_htm.xml      1   NaN
# 2          syn-20221206_htm.xml      1   NaN
# 3         fitb-20221206_htm.xml      1   NaN
# 4          glt-20221202_htm.xml      1   NaN
# ...                         ...    ...   ...
# 23938   cdxc20220930_8k_htm.xml      1   NaN
# 23939     rkly-20220930_htm.xml      1   NaN
# 23940     snti-20220930_htm.xml      1   NaN
# 23941     xers-20220929_htm.xml      1   NaN
# 23942     rivn-20221003_htm.xml      1   NaN
#
# [23943 rows x 25 columns]

# %%
df = pd.read_csv("/Users/matthesfogtmann/Downloads/SEC data/2022q2/SUB.txt",sep="\t")

# %%
df["bas1"].iloc[0]
# Out:
# '5260 CALIFORNIA AVENUE'

# %%
import geopandas

# %%
df = geopandas.tools.geocode('5260 CALIFORNIA AVENUE')

# %%
df["long"] = df["geometry"].apply(lambda a: a.centroid.x)
df["lat"] = df["geometry"][0].centroid.y

# %%
df
# Out:
#                       geometry  \
# 0  POINT (-117.04063 32.77397)
#
#                                              address         lat       long
# 0  5260, Guessman Avenue, 91942, Guessman Avenue,... -117.040634  32.773968

# %%
locator = Nominatim(user_agent=”myGeocoder”)
location = locator.geocode(“Champ de Mars, Paris, France”)

# %%
import plotly.express as px

fig = px.scatter_geo(df, lat="lat",lon="long",size=[10])
#fig.show()

# %%
df["geometry"][0].centroid.x
# Out:
# -117.040634

# %%
getTicker("10X GENOMICS, INC.")
# Out:
# 'TXG'

# %%
report
# Out:
#                                                                                           BS  \
# 1 800 FLOWERS COM INC                      {'AdditionalPaidInCapital': 378741000.0, 'Othe...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'AccountsPayableCurrent': 255700.0, 'Liabilit...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'AccountsPayableCurrent': 103609.0, 'Liabilit...
#
#                                                                                           CF  \
# 1 800 FLOWERS COM INC                      {'IncreaseDecreaseInInventories': 51928000.0, ...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'CashAndCashEquivalentsPeriodIncreaseDecrease...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'CashAndCashEquivalentsPeriodIncreaseDecrease...
#
#                                                                                           IS  \
# 1 800 FLOWERS COM INC                      {'WeightedAverageNumberOfSharesOutstandingBasi...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'RelatedPartyTransactionSellingGeneralAndAdmi...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'RelatedPartyTransactionSellingGeneralAndAdmi...
#
#                                                                                           EQ  \
# 1 800 FLOWERS COM INC                      {'StockIssuedDuringPeriodValueShareBasedCompen...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'NetIncomeLoss': -1906041.0, 'StockIssuedDuri...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'NetIncomeLoss': -347368.0, 'StockIssuedDurin...
#
#                                            CP  CI  UN
# 1 800 FLOWERS COM INC                      {}  {}  {}
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {}  {}  {}
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {}  {}  {}

# %%
report = getFinacialData(path+"2022q2"+"/")
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  4.58it/s]

# %%
report
# Out:
#                                                                                           BS  \
# 1 800 FLOWERS COM INC                      {'AdditionalPaidInCapital': 378741000.0, 'Othe...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'AccountsPayableCurrent': 255700.0, 'Liabilit...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'AccountsPayableCurrent': 103609.0, 'Liabilit...
#
#                                                                                           CF  \
# 1 800 FLOWERS COM INC                      {'IncreaseDecreaseInInventories': 51928000.0, ...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'CashAndCashEquivalentsPeriodIncreaseDecrease...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'CashAndCashEquivalentsPeriodIncreaseDecrease...
#
#                                                                                           IS  \
# 1 800 FLOWERS COM INC                      {'WeightedAverageNumberOfSharesOutstandingBasi...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'RelatedPartyTransactionSellingGeneralAndAdmi...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'RelatedPartyTransactionSellingGeneralAndAdmi...
#
#                                                                                           EQ  \
# 1 800 FLOWERS COM INC                      {'StockIssuedDuringPeriodValueShareBasedCompen...
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {'NetIncomeLoss': -1906041.0, 'StockIssuedDuri...
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {'NetIncomeLoss': -347368.0, 'StockIssuedDurin...
#
#                                            CP  CI  UN
# 1 800 FLOWERS COM INC                      {}  {}  {}
# 10X CAPITAL VENTURE ACQUISITION CORP. II   {}  {}  {}
# 10X CAPITAL VENTURE ACQUISITION CORP. III  {}  {}  {}

# %%
newreport = getFinacialData(path+"2022q2"+"/")
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.06it/s]

# %%
combineReports(report).T
# Out:
#                                                    1 800 FLOWERS COM INC      \
#                                                                       BS  CF
# AdditionalPaidInCapital                                      378741000.0 NaN
# OtherLiabilitiesNoncurrent                                    21802000.0 NaN
# OperatingLeaseLiabilityNoncurrent                            125831000.0 NaN
# AccruedLiabilitiesCurrent                                    176551000.0 NaN
# PreferredStockSharesIssued                                           0.0 NaN
# ...                                                                  ...  ..
# PaymentsToAcquireRestrictedInvestments                               NaN NaN
# DeferredUnderwritingCommissionsIncurredButNotYe...                   NaN NaN
# RepaymentsOfRelatedPartyDebt                                         NaN NaN
# TemporaryEquityAccretionToRedemptionValue                            NaN NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued...                   NaN NaN
#
#                                                                         \
#                                                     IS  EQ  CP  CI  UN
# AdditionalPaidInCapital                            NaN NaN NaN NaN NaN
# OtherLiabilitiesNoncurrent                         NaN NaN NaN NaN NaN
# OperatingLeaseLiabilityNoncurrent                  NaN NaN NaN NaN NaN
# AccruedLiabilitiesCurrent                          NaN NaN NaN NaN NaN
# PreferredStockSharesIssued                         NaN NaN NaN NaN NaN
# ...                                                 ..  ..  ..  ..  ..
# PaymentsToAcquireRestrictedInvestments             NaN NaN NaN NaN NaN
# DeferredUnderwritingCommissionsIncurredButNotYe... NaN NaN NaN NaN NaN
# RepaymentsOfRelatedPartyDebt                       NaN NaN NaN NaN NaN
# TemporaryEquityAccretionToRedemptionValue          NaN NaN NaN NaN NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued... NaN NaN NaN NaN NaN
#
#                                                    10X CAPITAL VENTURE ACQUISITION CORP. II  \
#                                                                                          BS
# AdditionalPaidInCapital                                                                 NaN
# OtherLiabilitiesNoncurrent                                                              NaN
# OperatingLeaseLiabilityNoncurrent                                                       NaN
# AccruedLiabilitiesCurrent                                                         2475592.0
# PreferredStockSharesIssued                                                              0.0
# ...                                                                                     ...
# PaymentsToAcquireRestrictedInvestments                                                  NaN
# DeferredUnderwritingCommissionsIncurredButNotYe...                                      NaN
# RepaymentsOfRelatedPartyDebt                                                            NaN
# TemporaryEquityAccretionToRedemptionValue                                               NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued...                                      NaN
#
#                                                             ...              \
#                                                     CF  IS  ...  CP  CI  UN
# AdditionalPaidInCapital                            NaN NaN  ... NaN NaN NaN
# OtherLiabilitiesNoncurrent                         NaN NaN  ... NaN NaN NaN
# OperatingLeaseLiabilityNoncurrent                  NaN NaN  ... NaN NaN NaN
# AccruedLiabilitiesCurrent                          NaN NaN  ... NaN NaN NaN
# PreferredStockSharesIssued                         NaN NaN  ... NaN NaN NaN
# ...                                                 ..  ..  ...  ..  ..  ..
# PaymentsToAcquireRestrictedInvestments             NaN NaN  ... NaN NaN NaN
# DeferredUnderwritingCommissionsIncurredButNotYe... NaN NaN  ... NaN NaN NaN
# RepaymentsOfRelatedPartyDebt                       NaN NaN  ... NaN NaN NaN
# TemporaryEquityAccretionToRedemptionValue          NaN NaN  ... NaN NaN NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued... NaN NaN  ... NaN NaN NaN
#
#                                                    10X CAPITAL VENTURE ACQUISITION CORP. III  \
#                                                                                           BS
# AdditionalPaidInCapital                                                                  0.0
# OtherLiabilitiesNoncurrent                                                               NaN
# OperatingLeaseLiabilityNoncurrent                                                        NaN
# AccruedLiabilitiesCurrent                                                           244584.0
# PreferredStockSharesIssued                                                               0.0
# ...                                                                                      ...
# PaymentsToAcquireRestrictedInvestments                                                   NaN
# DeferredUnderwritingCommissionsIncurredButNotYe...                                       NaN
# RepaymentsOfRelatedPartyDebt                                                             NaN
# TemporaryEquityAccretionToRedemptionValue                                                NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued...                                       NaN
#
#                                                                      \
#                                                              CF  IS
# AdditionalPaidInCapital                                     NaN NaN
# OtherLiabilitiesNoncurrent                                  NaN NaN
# OperatingLeaseLiabilityNoncurrent                           NaN NaN
# AccruedLiabilitiesCurrent                                   NaN NaN
# PreferredStockSharesIssued                                  NaN NaN
# ...                                                         ...  ..
# PaymentsToAcquireRestrictedInvestments              304500000.0 NaN
# DeferredUnderwritingCommissionsIncurredButNotYe...   14280000.0 NaN
# RepaymentsOfRelatedPartyDebt                           136617.0 NaN
# TemporaryEquityAccretionToRedemptionValue                   NaN NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued...          NaN NaN
#
#
#                                                             EQ  CP  CI  UN
# AdditionalPaidInCapital                                    NaN NaN NaN NaN
# OtherLiabilitiesNoncurrent                                 NaN NaN NaN NaN
# OperatingLeaseLiabilityNoncurrent                          NaN NaN NaN NaN
# AccruedLiabilitiesCurrent                                  NaN NaN NaN NaN
# PreferredStockSharesIssued                                 NaN NaN NaN NaN
# ...                                                        ...  ..  ..  ..
# PaymentsToAcquireRestrictedInvestments                     NaN NaN NaN NaN
# DeferredUnderwritingCommissionsIncurredButNotYe...         NaN NaN NaN NaN
# RepaymentsOfRelatedPartyDebt                               NaN NaN NaN NaN
# TemporaryEquityAccretionToRedemptionValue           36210782.0 NaN NaN NaN
# AdjustmentsToAdditionalPaidInCapitalStockIssued...    829867.0 NaN NaN NaN
#
# [113 rows x 21 columns]

# %%
def getTicker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
getTicker("2U, INC.")
# Out:
# <Response [200]>
# 'TWOU'

# %%
reports = {i : combineReports(getFinacialData(path+i+"/")) for i in getDir(path)}
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  4.71it/s]
# 100%|██████████| 3/3 [00:00<00:00,  4.85it/s]
# 100%|██████████| 3/3 [00:00<00:00,  4.79it/s]
# <ipython-input-36-060c1b2ee209>:9: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = {i:pd.read_csv(f"{filename}{i}.txt",sep="\t") for i in ["tag","num","pre","sub"]}
# 100%|██████████| 3/3 [00:00<00:00,  3.96it/s]

# %%
reports
# Out:
# {'2022q2':                                               AdditionalPaidInCapital  \
#  1 800 FLOWERS COM INC                     BS              378741000.0
#                                            CF                      NaN
#                                            IS                      NaN
#                                            EQ                      NaN
#                                            CP                      NaN
#                                            CI                      NaN
#                                            UN                      NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                      NaN
#                                            CF                      NaN
#                                            IS                      NaN
#                                            EQ                      NaN
#                                            CP                      NaN
#                                            CI                      NaN
#                                            UN                      NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                      0.0
#                                            CF                      NaN
#                                            IS                      NaN
#                                            EQ                      NaN
#                                            CP                      NaN
#                                            CI                      NaN
#                                            UN                      NaN
#
#                                                OtherLiabilitiesNoncurrent  \
#  1 800 FLOWERS COM INC                     BS                  21802000.0
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                         NaN
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                         NaN
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#
#                                                OperatingLeaseLiabilityNoncurrent  \
#  1 800 FLOWERS COM INC                     BS                        125831000.0
#                                            CF                                NaN
#                                            IS                                NaN
#                                            EQ                                NaN
#                                            CP                                NaN
#                                            CI                                NaN
#                                            UN                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                NaN
#                                            CF                                NaN
#                                            IS                                NaN
#                                            EQ                                NaN
#                                            CP                                NaN
#                                            CI                                NaN
#                                            UN                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                NaN
#                                            CF                                NaN
#                                            IS                                NaN
#                                            EQ                                NaN
#                                            CP                                NaN
#                                            CI                                NaN
#                                            UN                                NaN
#
#                                                AccruedLiabilitiesCurrent  \
#  1 800 FLOWERS COM INC                     BS                176551000.0
#                                            CF                        NaN
#                                            IS                        NaN
#                                            EQ                        NaN
#                                            CP                        NaN
#                                            CI                        NaN
#                                            UN                        NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                  2475592.0
#                                            CF                        NaN
#                                            IS                        NaN
#                                            EQ                        NaN
#                                            CP                        NaN
#                                            CI                        NaN
#                                            UN                        NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                   244584.0
#                                            CF                        NaN
#                                            IS                        NaN
#                                            EQ                        NaN
#                                            CP                        NaN
#                                            CI                        NaN
#                                            UN                        NaN
#
#                                                PreferredStockSharesIssued  \
#  1 800 FLOWERS COM INC                     BS                         0.0
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                         0.0
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                         0.0
#                                            CF                         NaN
#                                            IS                         NaN
#                                            EQ                         NaN
#                                            CP                         NaN
#                                            CI                         NaN
#                                            UN                         NaN
#
#                                                PreferredStockSharesAuthorized  \
#  1 800 FLOWERS COM INC                     BS                      10000000.0
#                                            CF                             NaN
#                                            IS                             NaN
#                                            EQ                             NaN
#                                            CP                             NaN
#                                            CI                             NaN
#                                            UN                             NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                       1000000.0
#                                            CF                             NaN
#                                            IS                             NaN
#                                            EQ                             NaN
#                                            CP                             NaN
#                                            CI                             NaN
#                                            UN                             NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                       1000000.0
#                                            CF                             NaN
#                                            IS                             NaN
#                                            EQ                             NaN
#                                            CP                             NaN
#                                            CI                             NaN
#                                            UN                             NaN
#
#                                                DeferredIncomeTaxLiabilitiesNet  \
#  1 800 FLOWERS COM INC                     BS                       32484000.0
#                                            CF                              NaN
#                                            IS                              NaN
#                                            EQ                              NaN
#                                            CP                              NaN
#                                            CI                              NaN
#                                            UN                              NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                              NaN
#                                            CF                              NaN
#                                            IS                              NaN
#                                            EQ                              NaN
#                                            CP                              NaN
#                                            CI                              NaN
#                                            UN                              NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                              NaN
#                                            CF                              NaN
#                                            IS                              NaN
#                                            EQ                              NaN
#                                            CP                              NaN
#                                            CI                              NaN
#                                            UN                              NaN
#
#                                                LongTermDebtCurrent  \
#  1 800 FLOWERS COM INC                     BS           20000000.0
#                                            CF                  NaN
#                                            IS                  NaN
#                                            EQ                  NaN
#                                            CP                  NaN
#                                            CI                  NaN
#                                            UN                  NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                  NaN
#                                            CF                  NaN
#                                            IS                  NaN
#                                            EQ                  NaN
#                                            CP                  NaN
#                                            CI                  NaN
#                                            UN                  NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                  NaN
#                                            CF                  NaN
#                                            IS                  NaN
#                                            EQ                  NaN
#                                            CP                  NaN
#                                            CI                  NaN
#                                            UN                  NaN
#
#                                                PreferredStockParOrStatedValuePerShare  \
#  1 800 FLOWERS COM INC                     BS                                  0.0100
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                  0.0001
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                  0.0001
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#
#                                                CashAndCashEquivalentsAtCarryingValue  \
#  1 800 FLOWERS COM INC                     BS                             93025000.0
#                                            CF                                    NaN
#                                            IS                                    NaN
#                                            EQ                                    NaN
#                                            CP                                    NaN
#                                            CI                                    NaN
#                                            UN                                    NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                    NaN
#                                            CF                                    NaN
#                                            IS                                    NaN
#                                            EQ                                    NaN
#                                            CP                                    NaN
#                                            CI                                    NaN
#                                            UN                                    NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                    NaN
#                                            CF                                    NaN
#                                            IS                                    NaN
#                                            EQ                                    NaN
#                                            CP                                    NaN
#                                            CI                                    NaN
#                                            UN                                    NaN
#
#                                                ...  NotesIssued1  StockIssued1  \
#  1 800 FLOWERS COM INC                     BS  ...           NaN           NaN
#                                            CF  ...           NaN           NaN
#                                            IS  ...           NaN           NaN
#                                            EQ  ...           NaN           NaN
#                                            CP  ...           NaN           NaN
#                                            CI  ...           NaN           NaN
#                                            UN  ...           NaN           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS  ...           NaN           NaN
#                                            CF  ...           NaN           NaN
#                                            IS  ...           NaN           NaN
#                                            EQ  ...           NaN           NaN
#                                            CP  ...           NaN           NaN
#                                            CI  ...           NaN           NaN
#                                            UN  ...           NaN           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS  ...           NaN           NaN
#                                            CF  ...        1847.0           0.0
#                                            IS  ...           NaN           NaN
#                                            EQ  ...           NaN           NaN
#                                            CP  ...           NaN           NaN
#                                            CI  ...           NaN           NaN
#                                            UN  ...           NaN           NaN
#
#                                                OfferingCostsIncludedInAccruedExpenses  \
#  1 800 FLOWERS COM INC                     BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                     NaN
#                                            CF                                123854.0
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#
#                                                ProceedsFromIssuanceOfPrivatePlacement  \
#  1 800 FLOWERS COM INC                     BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                     NaN
#                                            CF                              11530000.0
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#
#                                                OfferingCostsIncludedInAccountsPayable  \
#  1 800 FLOWERS COM INC                     BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                     NaN
#                                            CF                                172025.0
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#
#                                                PaymentsToAcquireRestrictedInvestments  \
#  1 800 FLOWERS COM INC                     BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                     NaN
#                                            CF                                     NaN
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                     NaN
#                                            CF                             304500000.0
#                                            IS                                     NaN
#                                            EQ                                     NaN
#                                            CP                                     NaN
#                                            CI                                     NaN
#                                            UN                                     NaN
#
#                                                DeferredUnderwritingCommissionsIncurredButNotYetPaid  \
#  1 800 FLOWERS COM INC                     BS                                                NaN
#                                            CF                                                NaN
#                                            IS                                                NaN
#                                            EQ                                                NaN
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                                NaN
#                                            CF                                                NaN
#                                            IS                                                NaN
#                                            EQ                                                NaN
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                                NaN
#                                            CF                                         14280000.0
#                                            IS                                                NaN
#                                            EQ                                                NaN
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#
#                                                RepaymentsOfRelatedPartyDebt  \
#  1 800 FLOWERS COM INC                     BS                           NaN
#                                            CF                           NaN
#                                            IS                           NaN
#                                            EQ                           NaN
#                                            CP                           NaN
#                                            CI                           NaN
#                                            UN                           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                           NaN
#                                            CF                           NaN
#                                            IS                           NaN
#                                            EQ                           NaN
#                                            CP                           NaN
#                                            CI                           NaN
#                                            UN                           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                           NaN
#                                            CF                      136617.0
#                                            IS                           NaN
#                                            EQ                           NaN
#                                            CP                           NaN
#                                            CI                           NaN
#                                            UN                           NaN
#
#                                                TemporaryEquityAccretionToRedemptionValue  \
#  1 800 FLOWERS COM INC                     BS                                        NaN
#                                            CF                                        NaN
#                                            IS                                        NaN
#                                            EQ                                        NaN
#                                            CP                                        NaN
#                                            CI                                        NaN
#                                            UN                                        NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                        NaN
#                                            CF                                        NaN
#                                            IS                                        NaN
#                                            EQ                                        NaN
#                                            CP                                        NaN
#                                            CI                                        NaN
#                                            UN                                        NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                        NaN
#                                            CF                                        NaN
#                                            IS                                        NaN
#                                            EQ                                 36210782.0
#                                            CP                                        NaN
#                                            CI                                        NaN
#                                            UN                                        NaN
#
#                                                AdjustmentsToAdditionalPaidInCapitalStockIssuedIssuanceCosts
#  1 800 FLOWERS COM INC                     BS                                                NaN
#                                            CF                                                NaN
#                                            IS                                                NaN
#                                            EQ                                                NaN
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  BS                                                NaN
#                                            CF                                                NaN
#                                            IS                                                NaN
#                                            EQ                                                NaN
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III BS                                                NaN
#                                            CF                                                NaN
#                                            IS                                                NaN
#                                            EQ                                           829867.0
#                                            CP                                                NaN
#                                            CI                                                NaN
#                                            UN                                                NaN
#
#  [21 rows x 113 columns],
#  '2022q4':                                               StockIssuedDuringPeriodValueShareBasedCompensation  \
#  1 800 FLOWERS COM INC                     EQ                                          1555000.0
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ                                                NaN
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ                                                NaN
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#
#                                                StockholdersEquity  \
#  1 800 FLOWERS COM INC                     EQ         477272000.0
#                                            CP                 NaN
#                                            BS                 NaN
#                                            IS                 NaN
#                                            CF                 NaN
#                                            UN                 NaN
#                                            SI                 NaN
#                                            CI                 NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ         -14314771.0
#                                            CP                 NaN
#                                            BS         -14314771.0
#                                            IS                 NaN
#                                            CF                 NaN
#                                            UN                 NaN
#                                            SI                 NaN
#                                            CI                 NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ         -14333349.0
#                                            CP                 NaN
#                                            BS         -14333349.0
#                                            IS                 NaN
#                                            CF                 NaN
#                                            UN                 NaN
#                                            SI                 NaN
#                                            CI                 NaN
#
#                                                NetIncomeLoss  \
#  1 800 FLOWERS COM INC                     EQ    -33692000.0
#                                            CP            NaN
#                                            BS            NaN
#                                            IS    -33692000.0
#                                            CF    -33692000.0
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ      -925998.0
#                                            CP            NaN
#                                            BS            NaN
#                                            IS      -925998.0
#                                            CF      -925998.0
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ      1111967.0
#                                            CP            NaN
#                                            BS            NaN
#                                            IS      1111967.0
#                                            CF      1111967.0
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
#
#                                                StockIssuedDuringPeriodValueStockOptionsExercised  \
#  1 800 FLOWERS COM INC                     EQ                                           563000.0
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ                                                NaN
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ                                                NaN
#                                            CP                                                NaN
#                                            BS                                                NaN
#                                            IS                                                NaN
#                                            CF                                                NaN
#                                            UN                                                NaN
#                                            SI                                                NaN
#                                            CI                                                NaN
#
#                                                TreasuryStockValueAcquiredCostMethod  \
#  1 800 FLOWERS COM INC                     EQ                             9065000.0
#                                            CP                                   NaN
#                                            BS                                   NaN
#                                            IS                                   NaN
#                                            CF                                   NaN
#                                            UN                                   NaN
#                                            SI                                   NaN
#                                            CI                                   NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ                                   NaN
#                                            CP                                   NaN
#                                            BS                                   NaN
#                                            IS                                   NaN
#                                            CF                                   NaN
#                                            UN                                   NaN
#                                            SI                                   NaN
#                                            CI                                   NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ                                   NaN
#                                            CP                                   NaN
#                                            BS                                   NaN
#                                            IS                                   NaN
#                                            CF                                   NaN
#                                            UN                                   NaN
#                                            SI                                   NaN
#                                            CI                                   NaN
#
#                                                AdditionalPaidInCapital  \
#  1 800 FLOWERS COM INC                     EQ                      NaN
#                                            CP                      NaN
#                                            BS              381440000.0
#                                            IS                      NaN
#                                            CF                      NaN
#                                            UN                      NaN
#                                            SI                      NaN
#                                            CI                      NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II  EQ                      NaN
#                                            CP                      NaN
#                                            BS                      NaN
#                                            IS                      NaN
#                                            CF                      NaN
#                                            UN                      NaN
#                                            SI                      NaN
#                                            CI                      NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. III EQ                      NaN
#                                            CP                      NaN
#                                            BS                      0.0
#                                            IS                      NaN
#                                            CF                      NaN
#                                            UN                      NaN
# ...
#                                           BS  ...                 1.100000e+09
#                                           CP  ...                          NaN
#
#                                               RestrictedCashCurrent  \
#  1 800 FLOWERS COM INC                    IS                    NaN
#                                           EQ                    NaN
#                                           CF                    NaN
#                                           CI                    NaN
#                                           UN                    NaN
#                                           BS                    NaN
#                                           CP                    NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                    NaN
#                                           EQ                    NaN
#                                           CF                    NaN
#                                           CI                    NaN
#                                           UN                    NaN
#                                           BS                    NaN
#                                           CP                    NaN
#  10X GENOMICS, INC.                       IS                    NaN
#                                           EQ                    NaN
#                                           CF                    NaN
#                                           CI                    NaN
#                                           UN                    NaN
#                                           BS              1028000.0
#                                           CP                    NaN
#
#                                               CommonStockSharesIssued  \
#  1 800 FLOWERS COM INC                    IS                      NaN
#                                           EQ                      NaN
#                                           CF                      NaN
#                                           CI                      NaN
#                                           UN                      NaN
#                                           BS                      NaN
#                                           CP                      NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                      NaN
#                                           EQ                      NaN
#                                           CF                      NaN
#                                           CI                      NaN
#                                           UN                      NaN
#                                           BS                      NaN
#                                           CP                      NaN
#  10X GENOMICS, INC.                       IS                      NaN
#                                           EQ                      NaN
#                                           CF                      NaN
#                                           CI                      NaN
#                                           UN                      NaN
#                                           BS              112514977.0
#                                           CP                      NaN
#
#                                               CashEquivalentsAtCarryingValue  \
#  1 800 FLOWERS COM INC                    IS                             NaN
#                                           EQ                             NaN
#                                           CF                             NaN
#                                           CI                             NaN
#                                           UN                             NaN
#                                           BS                             NaN
#                                           CP                             NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                             NaN
#                                           EQ                             NaN
#                                           CF                             NaN
#                                           CI                             NaN
#                                           UN                             NaN
#                                           BS                             NaN
#                                           CP                             NaN
#  10X GENOMICS, INC.                       IS                             NaN
#                                           EQ                             NaN
#                                           CF                             NaN
#                                           CI                             NaN
#                                           UN                             NaN
#                                           BS                     587447000.0
#                                           CP                             NaN
#
#                                               CommonStockParOrStatedValuePerShare  \
#  1 800 FLOWERS COM INC                    IS                                  NaN
#                                           EQ                                  NaN
#                                           CF                                  NaN
#                                           CI                                  NaN
#                                           UN                                  NaN
#                                           BS                                  NaN
#                                           CP                                  NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                                  NaN
#                                           EQ                                  NaN
#                                           CF                                  NaN
#                                           CI                                  NaN
#                                           UN                                  NaN
#                                           BS                                  NaN
#                                           CP                                  NaN
#  10X GENOMICS, INC.                       IS                                  NaN
#                                           EQ                                  NaN
#                                           CF                                  NaN
#                                           CI                                  NaN
#                                           UN                                  NaN
#                                           BS                                  0.0
#                                           CP                                  NaN
#
#                                               CommonStockSharesOutstanding  \
#  1 800 FLOWERS COM INC                    IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                           NaN
#                                           CP                           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                           NaN
#                                           CP                           NaN
#  10X GENOMICS, INC.                       IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                   112514977.0
#                                           CP                           NaN
#
#                                               ContractWithCustomerLiabilityCurrent  \
#  1 800 FLOWERS COM INC                    IS                                   NaN
#                                           EQ                                   NaN
#                                           CF                                   NaN
#                                           CI                                   NaN
#                                           UN                                   NaN
#                                           BS                                   NaN
#                                           CP                                   NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                                   NaN
#                                           EQ                                   NaN
#                                           CF                                   NaN
#                                           CI                                   NaN
#                                           UN                                   NaN
#                                           BS                                   NaN
#                                           CP                                   NaN
#  10X GENOMICS, INC.                       IS                                   NaN
#                                           EQ                                   NaN
#                                           CF                                   NaN
#                                           CI                                   NaN
#                                           UN                                   NaN
#                                           BS                             5340000.0
#                                           CP                                   NaN
#
#                                               AdditionalPaidInCapitalCommonStock  \
#  1 800 FLOWERS COM INC                    IS                                 NaN
#                                           EQ                                 NaN
#                                           CF                                 NaN
#                                           CI                                 NaN
#                                           UN                                 NaN
#                                           BS                                 NaN
#                                           CP                                 NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                                 NaN
#                                           EQ                                 NaN
#                                           CF                                 NaN
#                                           CI                                 NaN
#                                           UN                                 NaN
#                                           BS                                 NaN
#                                           CP                                 NaN
#  10X GENOMICS, INC.                       IS                                 NaN
#                                           EQ                                 NaN
#                                           CF                                 NaN
#                                           CI                                 NaN
#                                           UN                                 NaN
#                                           BS                        1.680865e+09
#                                           CP                                 NaN
#
#                                               EmployeeRelatedLiabilitiesCurrent  \
#  1 800 FLOWERS COM INC                    IS                                NaN
#                                           EQ                                NaN
#                                           CF                                NaN
#                                           CI                                NaN
#                                           UN                                NaN
#                                           BS                                NaN
#                                           CP                                NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                                NaN
#                                           EQ                                NaN
#                                           CF                                NaN
#                                           CI                                NaN
#                                           UN                                NaN
#                                           BS                                NaN
#                                           CP                                NaN
#  10X GENOMICS, INC.                       IS                                NaN
#                                           EQ                                NaN
#                                           CF                                NaN
#                                           CI                                NaN
#                                           UN                                NaN
#                                           BS                         31626000.0
#                                           CP                                NaN
#
#                                               LicenseFeesAccruedNoncurrent
#  1 800 FLOWERS COM INC                    IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                           NaN
#                                           CP                           NaN
#  10X CAPITAL VENTURE ACQUISITION CORP. II IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                           NaN
#                                           CP                           NaN
#  10X GENOMICS, INC.                       IS                           NaN
#                                           EQ                           NaN
#                                           CF                           NaN
#                                           CI                           NaN
#                                           UN                           NaN
#                                           BS                     5814000.0
#                                           CP                           NaN
#
#  [21 rows x 178 columns]}

# %%
dataset = combineReports(reports)
# Out:
# 2022q2
# 2022q4
# 2022q3
# 2022q1
# {'AdditionalPaidInCapital': {'2022q2': 1 800 FLOWERS COM INC                      BS    378741000.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS            0.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# Name: AdditionalPaidInCapital, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ            NaN
#                                            CP            NaN
#                                            BS    381440000.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ            NaN
#                                            CP            NaN
#                                            BS            NaN
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ            NaN
#                                            CP            NaN
#                                            BS            0.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# Name: AdditionalPaidInCapital, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    379885000.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS            NaN
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS            0.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# Name: AdditionalPaidInCapital, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    377234000.0
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            0.0
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# Name: AdditionalPaidInCapital, dtype: float64}, 'OtherLiabilitiesNoncurrent': {'2022q2': 1 800 FLOWERS COM INC                      BS    21802000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# Name: OtherLiabilitiesNoncurrent, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ           NaN
#                                            CP           NaN
#                                            BS    17434000.0
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ           NaN
#                                            CP           NaN
#                                            BS           NaN
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ           NaN
#                                            CP           NaN
#                                            BS           NaN
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# Name: OtherLiabilitiesNoncurrent, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    17884000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# Name: OtherLiabilitiesNoncurrent, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS    22112000.0
#                                           CP           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X GENOMICS, INC.                        IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS     8240000.0
#                                           CP           NaN
# Name: OtherLiabilitiesNoncurrent, dtype: float64}, 'OperatingLeaseLiabilityNoncurrent': {'2022q2': 1 800 FLOWERS COM INC                      BS    125831000.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# Name: OperatingLeaseLiabilityNoncurrent, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ            NaN
#                                            CP            NaN
#                                            BS    128521000.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ            NaN
#                                            CP            NaN
#                                            BS            NaN
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ            NaN
#                                            CP            NaN
#                                            BS            NaN
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# Name: OperatingLeaseLiabilityNoncurrent, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    123662000.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS            NaN
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS            NaN
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# Name: OperatingLeaseLiabilityNoncurrent, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    128620000.0
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS     76847000.0
#                                           CP            NaN
# Name: OperatingLeaseLiabilityNoncurrent, dtype: float64}, 'AccruedLiabilitiesCurrent': {'2022q2': 1 800 FLOWERS COM INC                      BS    176551000.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS      2475592.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS       244584.0
#                                            CF            NaN
#                                            IS            NaN
#                                            EQ            NaN
#                                            CP            NaN
#                                            CI            NaN
#                                            UN            NaN
# Name: AccruedLiabilitiesCurrent, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ            NaN
#                                            CP            NaN
#                                            BS    180915000.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ            NaN
#                                            CP            NaN
#                                            BS      5056885.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ            NaN
#                                            CP            NaN
#                                            BS       158279.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# Name: AccruedLiabilitiesCurrent, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    175392000.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS      4297453.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS       201149.0
#                                            CP            NaN
#                                            EQ            NaN
#                                            UN            NaN
#                                            CF            NaN
#                                            IS            NaN
#                                            CI            NaN
# Name: AccruedLiabilitiesCurrent, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    279345000.0
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS      1063040.0
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# Name: AccruedLiabilitiesCurrent, dtype: float64}, 'PreferredStockSharesIssued': {'2022q2': 1 800 FLOWERS COM INC                      BS    0.0
#                                            CF    NaN
#                                            IS    NaN
#                                            EQ    NaN
#                                            CP    NaN
#                                            CI    NaN
#                                            UN    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS    0.0
#                                            CF    NaN
#                                            IS    NaN
#                                            EQ    NaN
#                                            CP    NaN
#                                            CI    NaN
#                                            UN    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS    0.0
#                                            CF    NaN
#                                            IS    NaN
#                                            EQ    NaN
#                                            CP    NaN
#                                            CI    NaN
#                                            UN    NaN
# Name: PreferredStockSharesIssued, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ    NaN
#                                            CP    NaN
#                                            BS    0.0
#                                            IS    NaN
#                                            CF    NaN
#                                            UN    NaN
#                                            SI    NaN
#                                            CI    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ    NaN
#                                            CP    NaN
#                                            BS    0.0
#                                            IS    NaN
#                                            CF    NaN
#                                            UN    NaN
#                                            SI    NaN
#                                            CI    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ    NaN
#                                            CP    NaN
#                                            BS    0.0
#                                            IS    NaN
#                                            CF    NaN
#                                            UN    NaN
#                                            SI    NaN
#                                            CI    NaN
# Name: PreferredStockSharesIssued, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    0.0
#                                            CP    NaN
#                                            EQ    NaN
#                                            UN    NaN
#                                            CF    NaN
#                                            IS    NaN
#                                            CI    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS    0.0
#                                            CP    NaN
#                                            EQ    NaN
#                                            UN    NaN
#                                            CF    NaN
#                                            IS    NaN
#                                            CI    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS    0.0
#                                            CP    NaN
#                                            EQ    NaN
#                                            UN    NaN
#                                            CF    NaN
#                                            IS    NaN
#                                            CI    NaN
# Name: PreferredStockSharesIssued, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    0.0
#                                           CP    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    0.0
#                                           CP    NaN
# 10X GENOMICS, INC.                        IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    0.0
#                                           CP    NaN
# Name: PreferredStockSharesIssued, dtype: float64}, 'PreferredStockSharesAuthorized': {'2022q2': 1 800 FLOWERS COM INC                      BS    10000000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS     1000000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS     1000000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# Name: PreferredStockSharesAuthorized, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ           NaN
#                                            CP           NaN
#                                            BS    10000000.0
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ           NaN
#                                            CP           NaN
#                                            BS     1000000.0
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ           NaN
#                                            CP           NaN
#                                            BS     1000000.0
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# Name: PreferredStockSharesAuthorized, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    10000000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS     1000000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS     1000000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# Name: PreferredStockSharesAuthorized, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS     10000000.0
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS      1000000.0
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    100000000.0
#                                           CP            NaN
# Name: PreferredStockSharesAuthorized, dtype: float64}, 'DeferredIncomeTaxLiabilitiesNet': {'2022q2': 1 800 FLOWERS COM INC                      BS    32484000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# Name: DeferredIncomeTaxLiabilitiesNet, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ           NaN
#                                            CP           NaN
#                                            BS    35361000.0
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ           NaN
#                                            CP           NaN
#                                            BS           NaN
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ           NaN
#                                            CP           NaN
#                                            BS           NaN
#                                            IS           NaN
#                                            CF           NaN
#                                            UN           NaN
#                                            SI           NaN
#                                            CI           NaN
# Name: DeferredIncomeTaxLiabilitiesNet, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    35742000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# Name: DeferredIncomeTaxLiabilitiesNet, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS    32856000.0
#                                           CP           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X GENOMICS, INC.                        IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# Name: DeferredIncomeTaxLiabilitiesNet, dtype: float64}, 'LongTermDebtCurrent': {'2022q2': 1 800 FLOWERS COM INC                      BS    20000000.0
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            EQ           NaN
#                                            CP           NaN
#                                            CI           NaN
#                                            UN           NaN
# Name: LongTermDebtCurrent, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ            NaN
#                                            CP            NaN
#                                            BS    160000000.0
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ            NaN
#                                            CP            NaN
#                                            BS            NaN
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ            NaN
#                                            CP            NaN
#                                            BS            NaN
#                                            IS            NaN
#                                            CF            NaN
#                                            UN            NaN
#                                            SI            NaN
#                                            CI            NaN
# Name: LongTermDebtCurrent, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    20000000.0
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS           NaN
#                                            CP           NaN
#                                            EQ           NaN
#                                            UN           NaN
#                                            CF           NaN
#                                            IS           NaN
#                                            CI           NaN
# Name: LongTermDebtCurrent, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS    20000000.0
#                                           CP           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X GENOMICS, INC.                        IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# Name: LongTermDebtCurrent, dtype: float64}, 'PreferredStockParOrStatedValuePerShare': {'2022q2': 1 800 FLOWERS COM INC                      BS    0.0100
#                                            CF       NaN
#                                            IS       NaN
#                                            EQ       NaN
#                                            CP       NaN
#                                            CI       NaN
#                                            UN       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS    0.0001
#                                            CF       NaN
#                                            IS       NaN
#                                            EQ       NaN
#                                            CP       NaN
#                                            CI       NaN
#                                            UN       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS    0.0001
#                                            CF       NaN
#                                            IS       NaN
#                                            EQ       NaN
#                                            CP       NaN
#                                            CI       NaN
#                                            UN       NaN
# Name: PreferredStockParOrStatedValuePerShare, dtype: float64, '2022q4': 1 800 FLOWERS COM INC                      EQ       NaN
#                                            CP       NaN
#                                            BS    0.0100
#                                            IS       NaN
#                                            CF       NaN
#                                            UN       NaN
#                                            SI       NaN
#                                            CI       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   EQ       NaN
#                                            CP       NaN
#                                            BS    0.0001
#                                            IS       NaN
#                                            CF       NaN
#                                            UN       NaN
#                                            SI       NaN
#                                            CI       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  EQ       NaN
#                                            CP       NaN
#                                            BS    0.0001
#                                            IS       NaN
#                                            CF       NaN
#                                            UN       NaN
#                                            SI       NaN
#                                            CI       NaN
# Name: PreferredStockParOrStatedValuePerShare, dtype: float64, '2022q3': 1 800 FLOWERS COM INC                      BS    0.0100
#                                            CP       NaN
#                                            EQ       NaN
#                                            UN       NaN
#                                            CF       NaN
#                                            IS       NaN
#                                            CI       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II   BS    0.0001
#                                            CP       NaN
#                                            EQ       NaN
#                                            UN       NaN
#                                            CF       NaN
#                                            IS       NaN
#                                            CI       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. III  BS    0.0001
#                                            CP       NaN
#                                            EQ       NaN
#                                            UN       NaN
#                                            CF       NaN
#                                            IS       NaN
#                                            CI       NaN
# Name: PreferredStockParOrStatedValuePerShare, dtype: float64, '2022q1': 1 800 FLOWERS COM INC                     IS       NaN
#                                           EQ       NaN
#                                           CF       NaN
#                                           CI       NaN
#                                           UN       NaN
#                                           BS    0.0100
#                                           CP       NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS       NaN
#                                           EQ       NaN
# ...
#                                           CP          NaN
# Name: RestrictedCashNoncurrent, dtype: float64}, 'LitigationReserveCurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    NaN
#                                           CP    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    NaN
#                                           CP    NaN
# 10X GENOMICS, INC.                        IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    0.0
#                                           CP    NaN
# Name: LitigationReserveCurrent, dtype: float64}, 'AccruedExpensesandOtherLiabilitiesCurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X GENOMICS, INC.                        IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS    50909000.0
#                                           CP           NaN
# Name: AccruedExpensesandOtherLiabilitiesCurrent, dtype: float64}, 'CommonStockSharesAuthorized': {'2022q1': 1 800 FLOWERS COM INC                     IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS             NaN
#                                           CP             NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS             NaN
#                                           CP             NaN
# 10X GENOMICS, INC.                        IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS    1.100000e+09
#                                           CP             NaN
# Name: CommonStockSharesAuthorized, dtype: float64}, 'RestrictedCashCurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X GENOMICS, INC.                        IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS    1028000.0
#                                           CP          NaN
# Name: RestrictedCashCurrent, dtype: float64}, 'CommonStockSharesIssued': {'2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    112514977.0
#                                           CP            NaN
# Name: CommonStockSharesIssued, dtype: float64}, 'CashEquivalentsAtCarryingValue': {'2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    587447000.0
#                                           CP            NaN
# Name: CashEquivalentsAtCarryingValue, dtype: float64}, 'CommonStockParOrStatedValuePerShare': {'2022q1': 1 800 FLOWERS COM INC                     IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    NaN
#                                           CP    NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    NaN
#                                           CP    NaN
# 10X GENOMICS, INC.                        IS    NaN
#                                           EQ    NaN
#                                           CF    NaN
#                                           CI    NaN
#                                           UN    NaN
#                                           BS    0.0
#                                           CP    NaN
# Name: CommonStockParOrStatedValuePerShare, dtype: float64}, 'CommonStockSharesOutstanding': {'2022q1': 1 800 FLOWERS COM INC                     IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS            NaN
#                                           CP            NaN
# 10X GENOMICS, INC.                        IS            NaN
#                                           EQ            NaN
#                                           CF            NaN
#                                           CI            NaN
#                                           UN            NaN
#                                           BS    112514977.0
#                                           CP            NaN
# Name: CommonStockSharesOutstanding, dtype: float64}, 'ContractWithCustomerLiabilityCurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X GENOMICS, INC.                        IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS    5340000.0
#                                           CP          NaN
# Name: ContractWithCustomerLiabilityCurrent, dtype: float64}, 'AdditionalPaidInCapitalCommonStock': {'2022q1': 1 800 FLOWERS COM INC                     IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS             NaN
#                                           CP             NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS             NaN
#                                           CP             NaN
# 10X GENOMICS, INC.                        IS             NaN
#                                           EQ             NaN
#                                           CF             NaN
#                                           CI             NaN
#                                           UN             NaN
#                                           BS    1.680865e+09
#                                           CP             NaN
# Name: AdditionalPaidInCapitalCommonStock, dtype: float64}, 'EmployeeRelatedLiabilitiesCurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS           NaN
#                                           CP           NaN
# 10X GENOMICS, INC.                        IS           NaN
#                                           EQ           NaN
#                                           CF           NaN
#                                           CI           NaN
#                                           UN           NaN
#                                           BS    31626000.0
#                                           CP           NaN
# Name: EmployeeRelatedLiabilitiesCurrent, dtype: float64}, 'LicenseFeesAccruedNoncurrent': {'2022q1': 1 800 FLOWERS COM INC                     IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X CAPITAL VENTURE ACQUISITION CORP. II  IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS          NaN
#                                           CP          NaN
# 10X GENOMICS, INC.                        IS          NaN
#                                           EQ          NaN
#                                           CF          NaN
#                                           CI          NaN
#                                           UN          NaN
#                                           BS    5814000.0
#                                           CP          NaN
# Name: LicenseFeesAccruedNoncurrent, dtype: float64}}

# %%
dataset
# Out:
#        AdditionalPaidInCapital                              \
#          1 800 FLOWERS COM INC
#                             BS  CF  CI  CP  EQ  IS  SI  UN
# 2022q2             378741000.0 NaN NaN NaN NaN NaN NaN NaN
# 2022q4             381440000.0 NaN NaN NaN NaN NaN NaN NaN
# 2022q3             379885000.0 NaN NaN NaN NaN NaN NaN NaN
# 2022q1             377234000.0 NaN NaN NaN NaN NaN NaN NaN
#
#                                                      ...  \
#        10X CAPITAL VENTURE ACQUISITION CORP. II      ...
#                                              BS  CF  ...
# 2022q2                                      NaN NaN  ...
# 2022q4                                      NaN NaN  ...
# 2022q3                                      NaN NaN  ...
# 2022q1                                      0.0 NaN  ...
#
#                    LicenseFeesAccruedNoncurrent                             \
#        10X CAPITAL VENTURE ACQUISITION CORP. II         10X GENOMICS, INC.
#                                              UN  BS  CP                 IS
# 2022q2                                      NaN NaN NaN                NaN
# 2022q4                                      NaN NaN NaN                NaN
# 2022q3                                      NaN NaN NaN                NaN
# 2022q1                                      NaN NaN NaN                NaN
#
#
#
#         EQ  CF  CI  UN         BS  CP
# 2022q2 NaN NaN NaN NaN        NaN NaN
# 2022q4 NaN NaN NaN NaN        NaN NaN
# 2022q3 NaN NaN NaN NaN        NaN NaN
# 2022q1 NaN NaN NaN NaN  5814000.0 NaN
#
# [4 rows x 5033 columns]

# %%
dataset.to_csv("SECNewDAta.csv")

# %%
sec = pd.read_csv("SECNewDAta.csv",index_col=[0,1],header=[0,1])

# %%
sec["1 800 FLOWERS COM INC"]
# Out:
#                                                       BS  CF  CI  CP  EQ  IS  \
# AdditionalPaidInCapital              2022q2  378741000.0 NaN NaN NaN NaN NaN
#                                      2022q4  381440000.0 NaN NaN NaN NaN NaN
#                                      2022q3  379885000.0 NaN NaN NaN NaN NaN
#                                      2022q1  377234000.0 NaN NaN NaN NaN NaN
# OtherLiabilitiesNoncurrent           2022q2   21802000.0 NaN NaN NaN NaN NaN
# ...                                                  ...  ..  ..  ..  ..  ..
# CommonStockSharesOutstanding         2022q1          NaN NaN NaN NaN NaN NaN
# ContractWithCustomerLiabilityCurrent 2022q1          NaN NaN NaN NaN NaN NaN
# AdditionalPaidInCapitalCommonStock   2022q1          NaN NaN NaN NaN NaN NaN
# EmployeeRelatedLiabilitiesCurrent    2022q1          NaN NaN NaN NaN NaN NaN
# LicenseFeesAccruedNoncurrent         2022q1          NaN NaN NaN NaN NaN NaN
#
#                                              SI  UN
# AdditionalPaidInCapital              2022q2 NaN NaN
#                                      2022q4 NaN NaN
#                                      2022q3 NaN NaN
#                                      2022q1 NaN NaN
# OtherLiabilitiesNoncurrent           2022q2 NaN NaN
# ...                                          ..  ..
# CommonStockSharesOutstanding         2022q1 NaN NaN
# ContractWithCustomerLiabilityCurrent 2022q1 NaN NaN
# AdditionalPaidInCapitalCommonStock   2022q1 NaN NaN
# EmployeeRelatedLiabilitiesCurrent    2022q1 NaN NaN
# LicenseFeesAccruedNoncurrent         2022q1 NaN NaN
#
# [519 rows x 8 columns]

# %%
df = pd.DataFrame(dataset["1 800 FLOWERS COM INC"]["BS"])

# %%
df.reset_index(level=1)
# Out:
#                                           level_1           BS
# IntangibleAssetsNetExcludingGoodwill       2022q2  146641000.0
# IntangibleAssetsNetExcludingGoodwill       2022q4  144508000.0
# IntangibleAssetsNetExcludingGoodwill       2022q3  145568000.0
# IntangibleAssetsNetExcludingGoodwill       2022q1  147178000.0
# AssetsCurrent                              2022q2  381856000.0
# ...                                           ...          ...
# RestrictedCashNoncurrent                   2022q1          NaN
# CommonStockSharesOutstanding               2022q1          NaN
# AdditionalPaidInCapitalCommonStock         2022q1          NaN
# AccruedExpensesandOtherLiabilitiesCurrent  2022q1          NaN
# ContractWithCustomerLiabilityCurrent       2022q1          NaN
#
# [519 rows x 2 columns]

# %%
reports["2022q2"]["1 800 FLOWERS COM INC"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1 800 FLOWERS COM INC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-a1e25a060ae6> in <module>
# ----> 1 reports["2022q2"]["1 800 FLOWERS COM INC"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '1 800 FLOWERS COM INC'

# %%
reports["2022q2"]
# Out:
#                           AccumulatedOtherComprehensiveIncomeLossNetOfTax  \
# 1 800 FLOWERS COM INC BS                                        -318000.0
#                       CF                                              NaN
#                       IS                                              NaN
#                       EQ                                              NaN
#                       CP                                              NaN
# ...                                                                   ...
# 2U, INC.              IS                                              NaN
#                       EQ                                              NaN
#                       CP                                              NaN
#                       CI                                              NaN
#                       UN                                              NaN
#
#                           PrepaidExpenseAndOtherAssetsCurrent  \
# 1 800 FLOWERS COM INC BS                           33506000.0
#                       CF                                  NaN
#                       IS                                  NaN
#                       EQ                                  NaN
#                       CP                                  NaN
# ...                                                       ...
# 2U, INC.              IS                                  NaN
#                       EQ                                  NaN
#                       CP                                  NaN
#                       CI                                  NaN
#                       UN                                  NaN
#
#                           IntangibleAssetsNetExcludingGoodwill  \
# 1 800 FLOWERS COM INC BS                           146641000.0
#                       CF                                   NaN
#                       IS                                   NaN
#                       EQ                                   NaN
#                       CP                                   NaN
# ...                                                        ...
# 2U, INC.              IS                                   NaN
#                       EQ                                   NaN
#                       CP                                   NaN
#                       CI                                   NaN
#                       UN                                   NaN
#
#                           OperatingLeaseLiabilityCurrent  \
# 1 800 FLOWERS COM INC BS                      12518000.0
#                       CF                             NaN
#                       IS                             NaN
#                       EQ                             NaN
#                       CP                             NaN
# ...                                                  ...
# 2U, INC.              IS                             NaN
#                       EQ                             NaN
#                       CP                             NaN
#                       CI                             NaN
#                       UN                             NaN
#
#                           AccruedLiabilitiesCurrent     Goodwill  \
# 1 800 FLOWERS COM INC BS                176551000.0  213905000.0
#                       CF                        NaN          NaN
#                       IS                        NaN          NaN
#                       EQ                        NaN          NaN
#                       CP                        NaN          NaN
# ...                                             ...          ...
# 2U, INC.              IS                        NaN          NaN
#                       EQ                        NaN          NaN
#                       CP                        NaN          NaN
#                       CI                        NaN          NaN
#                       UN                        NaN          NaN
#
#                           OtherLiabilitiesNoncurrent  LongTermDebtCurrent  \
# 1 800 FLOWERS COM INC BS                  21802000.0           20000000.0
#                       CF                         NaN                  NaN
#                       IS                         NaN                  NaN
#                       EQ                         NaN                  NaN
#                       CP                         NaN                  NaN
# ...                                              ...                  ...
# 2U, INC.              IS                         NaN                  NaN
#                       EQ                         NaN                  NaN
#                       CP                         NaN                  NaN
#                       CI                         NaN                  NaN
#                       UN                         NaN                  NaN
#
#                                 Assets  OperatingLeaseRightOfUseAsset  ...  \
# 1 800 FLOWERS COM INC BS  1.128650e+09                    130897000.0  ...
#                       CF           NaN                            NaN  ...
#                       IS           NaN                            NaN  ...
#                       EQ           NaN                            NaN  ...
#                       CP           NaN                            NaN  ...
# ...                                ...                            ...  ...
# 2U, INC.              IS           NaN                            NaN  ...
#                       EQ           NaN                            NaN  ...
#                       CP           NaN                            NaN  ...
#                       CI           NaN                            NaN  ...
#                       UN           NaN                            NaN  ...
#
#                           RepaymentsOfOtherLongTermDebt  \
# 1 800 FLOWERS COM INC BS                            NaN
#                       CF                            NaN
#                       IS                            NaN
#                       EQ                            NaN
#                       CP                            NaN
# ...                                                 ...
# 2U, INC.              IS                            NaN
#                       EQ                            NaN
#                       CP                            NaN
#                       CI                            NaN
#                       UN                            NaN
#
#                           OtherOperatingActivitiesCashFlowStatement  \
# 1 800 FLOWERS COM INC BS                                        NaN
#                       CF                                        NaN
#                       IS                                        NaN
#                       EQ                                        NaN
#                       CP                                        NaN
# ...                                                             ...
# 2U, INC.              IS                                        NaN
#                       EQ                                        NaN
#                       CP                                        NaN
#                       CI                                        NaN
#                       UN                                        NaN
#
#                           ProceedsFromIssuanceOfDebt  \
# 1 800 FLOWERS COM INC BS                         NaN
#                       CF                         NaN
#                       IS                         NaN
#                       EQ                         NaN
#                       CP                         NaN
# ...                                              ...
# 2U, INC.              IS                         NaN
#                       EQ                         NaN
#                       CP                         NaN
#                       CI                         NaN
#                       UN                         NaN
#
#                           PaymentsRelatedToTaxWithholdingForShareBasedCompensation  \
# 1 800 FLOWERS COM INC BS                                                NaN
#                       CF                                                NaN
#                       IS                                                NaN
#                       EQ                                                NaN
#                       CP                                                NaN
# ...                                                                     ...
# 2U, INC.              IS                                                NaN
#                       EQ                                                NaN
#                       CP                                                NaN
#                       CI                                                NaN
#                       UN                                                NaN
#
#                           ReceivablesCreditLossExpenseReversal  \
# 1 800 FLOWERS COM INC BS                                   NaN
#                       CF                                   NaN
#                       IS                                   NaN
#                       EQ                                   NaN
#                       CP                                   NaN
# ...                                                        ...
# 2U, INC.              IS                                   NaN
#                       EQ                                   NaN
#                       CP                                   NaN
#                       CI                                   NaN
#                       UN                                   NaN
#
#                           TechnologyAndContentDevelopmentCost  \
# 1 800 FLOWERS COM INC BS                                  NaN
#                       CF                                  NaN
#                       IS                                  NaN
#                       EQ                                  NaN
#                       CP                                  NaN
# ...                                                       ...
# 2U, INC.              IS                           51057000.0
#                       EQ                                  NaN
#                       CP                                  NaN
#                       CI                                  NaN
#                       UN                                  NaN
#
#                           OtherComprehensiveIncomeLossForeignCurrencyTranslationAdjustmentTax  \
# 1 800 FLOWERS COM INC BS                                                NaN
#                       CF                                                NaN
#                       IS                                                NaN
#                       EQ                                                NaN
#                       CP                                                NaN
# ...                                                                     ...
# 2U, INC.              IS                                                0.0
#                       EQ                                                NaN
#                       CP                                                NaN
#                       CI                                                NaN
#                       UN                                                NaN
#
#                           CurriculumAndTeachingCosts  \
# 1 800 FLOWERS COM INC BS                         NaN
#                       CF                         NaN
#                       IS                         NaN
#                       EQ                         NaN
#                       CP                         NaN
# ...                                              ...
# 2U, INC.              IS                  33230000.0
#                       EQ                         NaN
#                       CP                         NaN
#                       CI                         NaN
#                       UN                         NaN
#
#                           ServicingAndSupportCosts  \
# 1 800 FLOWERS COM INC BS                       NaN
#                       CF                       NaN
#                       IS                       NaN
#                       EQ                       NaN
#                       CP                       NaN
# ...                                            ...
# 2U, INC.              IS                39624000.0
#                       EQ                       NaN
#                       CP                       NaN
#                       CI                       NaN
#                       UN                       NaN
#
#                           RestrictedStockValueSharesIssuedNetOfTaxWithholdings
# 1 800 FLOWERS COM INC BS                                                NaN
#                       CF                                                NaN
#                       IS                                                NaN
#                       EQ                                                NaN
#                       CP                                                NaN
# ...                                                                     ...
# 2U, INC.              IS                                                NaN
#                       EQ                                          -919000.0
#                       CP                                                NaN
#                       CI                                                NaN
#                       UN                                                NaN
#
# [140 rows x 780 columns]

# %%
reports["2022q2"]
# Out:
#                                               AccumulatedOtherComprehensiveIncomeLossNetOfTax  \
# BS 1 800 FLOWERS COM INC                                                            -318000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                               NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                              NaN
#    10X GENOMICS, INC.                                                              -2443000.0
#    111, INC.                                                                       59371000.0
# ...                                                                                       ...
# UN 22ND CENTURY GROUP, INC.                                                               NaN
#    23ANDME HOLDING CO.                                                                    NaN
#    26 CAPITAL ACQUISITION CORP.                                                           NaN
#    2SEVENTY BIO, INC.                                                                     NaN
#    2U, INC.                                                                               NaN
#
#                                               PrepaidExpenseAndOtherAssetsCurrent  \
# BS 1 800 FLOWERS COM INC                                               33506000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                   NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                  NaN
#    10X GENOMICS, INC.                                                  17762000.0
#    111, INC.                                                          242199000.0
# ...                                                                           ...
# UN 22ND CENTURY GROUP, INC.                                                   NaN
#    23ANDME HOLDING CO.                                                        NaN
#    26 CAPITAL ACQUISITION CORP.                                               NaN
#    2SEVENTY BIO, INC.                                                         NaN
#    2U, INC.                                                                   NaN
#
#                                               IntangibleAssetsNetExcludingGoodwill  \
# BS 1 800 FLOWERS COM INC                                               146641000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                   NaN
#    10X GENOMICS, INC.                                                   24764000.0
#    111, INC.                                                             4909000.0
# ...                                                                            ...
# UN 22ND CENTURY GROUP, INC.                                                    NaN
#    23ANDME HOLDING CO.                                                         NaN
#    26 CAPITAL ACQUISITION CORP.                                                NaN
#    2SEVENTY BIO, INC.                                                          NaN
#    2U, INC.                                                                    NaN
#
#                                               OperatingLeaseLiabilityCurrent  \
# BS 1 800 FLOWERS COM INC                                          12518000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                              NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                             NaN
#    10X GENOMICS, INC.                                              7637000.0
#    111, INC.                                                             NaN
# ...                                                                      ...
# UN 22ND CENTURY GROUP, INC.                                              NaN
#    23ANDME HOLDING CO.                                                   NaN
#    26 CAPITAL ACQUISITION CORP.                                          NaN
#    2SEVENTY BIO, INC.                                                    NaN
#    2U, INC.                                                              NaN
#
#                                               AccruedLiabilitiesCurrent  \
# BS 1 800 FLOWERS COM INC                                    176551000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                   2475592.0
#    10X CAPITAL VENTURE ACQUISITION CORP. III                   244584.0
#    10X GENOMICS, INC.                                               NaN
#    111, INC.                                                        NaN
# ...                                                                 ...
# UN 22ND CENTURY GROUP, INC.                                         NaN
#    23ANDME HOLDING CO.                                              NaN
#    26 CAPITAL ACQUISITION CORP.                                     NaN
#    2SEVENTY BIO, INC.                                               NaN
#    2U, INC.                                                         NaN
#
#                                                  Goodwill  \
# BS 1 800 FLOWERS COM INC                      213905000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II           NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III          NaN
#    10X GENOMICS, INC.                           4511000.0
#    111, INC.                                          NaN
# ...                                                   ...
# UN 22ND CENTURY GROUP, INC.                           NaN
#    23ANDME HOLDING CO.                                NaN
#    26 CAPITAL ACQUISITION CORP.                       NaN
#    2SEVENTY BIO, INC.                                 NaN
#    2U, INC.                                           NaN
#
#                                               OtherLiabilitiesNoncurrent  \
# BS 1 800 FLOWERS COM INC                                      21802000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                          NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                         NaN
#    10X GENOMICS, INC.                                          8582000.0
#    111, INC.                                                   1537000.0
# ...                                                                  ...
# UN 22ND CENTURY GROUP, INC.                                          NaN
#    23ANDME HOLDING CO.                                               NaN
#    26 CAPITAL ACQUISITION CORP.                                      NaN
#    2SEVENTY BIO, INC.                                                NaN
#    2U, INC.                                                          NaN
#
#                                               LongTermDebtCurrent  \
# BS 1 800 FLOWERS COM INC                               20000000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                   NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                  NaN
#    10X GENOMICS, INC.                                         NaN
#    111, INC.                                                  NaN
# ...                                                           ...
# UN 22ND CENTURY GROUP, INC.                                   NaN
#    23ANDME HOLDING CO.                                        NaN
#    26 CAPITAL ACQUISITION CORP.                               NaN
#    2SEVENTY BIO, INC.                                         NaN
#    2U, INC.                                                   NaN
#
#                                                     Assets  \
# BS 1 800 FLOWERS COM INC                      1.128650e+09
#    10X CAPITAL VENTURE ACQUISITION CORP. II   2.011796e+08
#    10X CAPITAL VENTURE ACQUISITION CORP. III  3.055506e+08
#    10X GENOMICS, INC.                         1.003251e+09
#    111, INC.                                  3.145833e+09
# ...                                                    ...
# UN 22ND CENTURY GROUP, INC.                            NaN
#    23ANDME HOLDING CO.                                 NaN
#    26 CAPITAL ACQUISITION CORP.                        NaN
#    2SEVENTY BIO, INC.                                  NaN
#    2U, INC.                                            NaN
#
#                                               OperatingLeaseRightOfUseAsset  \
# BS 1 800 FLOWERS COM INC                                        130897000.0
#    10X CAPITAL VENTURE ACQUISITION CORP. II                             NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                            NaN
#    10X GENOMICS, INC.                                            75680000.0
#    111, INC.                                                    233847000.0
# ...                                                                     ...
# UN 22ND CENTURY GROUP, INC.                                             NaN
#    23ANDME HOLDING CO.                                                  NaN
#    26 CAPITAL ACQUISITION CORP.                                         NaN
#    2SEVENTY BIO, INC.                                                   NaN
#    2U, INC.                                                             NaN
#
#                                               ...  EntityPublicFloat  \
# BS 1 800 FLOWERS COM INC                      ...                NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II   ...                NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III  ...                NaN
#    10X GENOMICS, INC.                         ...                NaN
#    111, INC.                                  ...                NaN
# ...                                           ...                ...
# UN 22ND CENTURY GROUP, INC.                   ...                NaN
#    23ANDME HOLDING CO.                        ...                NaN
#    26 CAPITAL ACQUISITION CORP.               ...                NaN
#    2SEVENTY BIO, INC.                         ...                NaN
#    2U, INC.                                   ...                NaN
#
#                                               EntityCommonStockSharesOutstanding  \
# BS 1 800 FLOWERS COM INC                                                     NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                  NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                 NaN
#    10X GENOMICS, INC.                                                        NaN
#    111, INC.                                                                 NaN
# ...                                                                          ...
# UN 22ND CENTURY GROUP, INC.                                                  NaN
#    23ANDME HOLDING CO.                                                       NaN
#    26 CAPITAL ACQUISITION CORP.                                              NaN
#    2SEVENTY BIO, INC.                                                        NaN
#    2U, INC.                                                                  NaN
#
#                                               OtherComprehensiveIncomeLossBeforeTaxPortionAttributableToParent  \
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
#                                               OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodBeforeTax  \
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
#                                               OtherComprehensiveIncomeLossTaxPortionAttributableToParent1  \
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
#                                               OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesBeforeTax  \
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
#                                               ReclassificationOfGainsLossesToNetIncome  \
# BS 1 800 FLOWERS COM INC                                                           NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                        NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                       NaN
#    10X GENOMICS, INC.                                                              NaN
#    111, INC.                                                                       NaN
# ...                                                                                ...
# UN 22ND CENTURY GROUP, INC.                                                        NaN
#    23ANDME HOLDING CO.                                                             NaN
#    26 CAPITAL ACQUISITION CORP.                                                    NaN
#    2SEVENTY BIO, INC.                                                              NaN
#    2U, INC.                                                                        NaN
#
#                                               OtherComprehensiveIncomeIncomeTaxProvisionBenefit  \
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
#                                               UnrealizedGainLossOnSecurities  \
# BS 1 800 FLOWERS COM INC                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                              NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                             NaN
#    10X GENOMICS, INC.                                                    NaN
#    111, INC.                                                             NaN
# ...                                                                      ...
# UN 22ND CENTURY GROUP, INC.                                              NaN
#    23ANDME HOLDING CO.                                                   NaN
#    26 CAPITAL ACQUISITION CORP.                                          NaN
#    2SEVENTY BIO, INC.                                                    NaN
#    2U, INC.                                                              NaN
#
#                                               OtherComprehensiveIncomeForeignCurrencyTranslationAdjustmentTaxPortionAttributableToParent
# BS 1 800 FLOWERS COM INC                                                                    NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. II                                                 NaN
#    10X CAPITAL VENTURE ACQUISITION CORP. III                                                NaN
#    10X GENOMICS, INC.                                                                       NaN
#    111, INC.                                                                                NaN
# ...                                                                                         ...
# UN 22ND CENTURY GROUP, INC.                                                                 NaN
#    23ANDME HOLDING CO.                                                                      NaN
#    26 CAPITAL ACQUISITION CORP.                                                             NaN
#    2SEVENTY BIO, INC.                                                                       NaN
#    2U, INC.                                                                                 NaN
#
# [140 rows x 780 columns]

# %%
dataset = combineReports(reports)

# %%
dataset["1 800 FLOWERS COM INC"]["BS"]
# Out:
# AccumulatedOtherComprehensiveIncomeLossNetOfTax            2022q2     -318000.0
#                                                            2022q4     -211000.0
#                                                            2022q3     -211000.0
#                                                            2022q1     -318000.0
# PrepaidExpenseAndOtherAssetsCurrent                        2022q2    33506000.0
#                                                                         ...
# TransferOfEquipmentToInventoryFromPropertyAndEquipmentNet  2022q1           NaN
# ContractWithCustomerLiabilityCustomerDepositsCurrent       2022q1           NaN
# OtherLongTermDebtNoncurrent                                2022q1           NaN
# StockBasedCompensation                                     2022q1           NaN
# PaymentsToAcquireTradingSecuritiesHeldforinvestment        2022q1           NaN
# Name: BS, Length: 3417, dtype: float64

# %%
dataset.to_csv('test.csv')

# %%
stmt_dic = {"BS" : "Balance Sheet", "IS" : "Income Statement", "CF" : "Cash Flow", "EQ" : "Equity",
 "CI": "Comprehensive Income", "UN" : "Unclassifiable Statement", "CP" :"Cover Page"}

# %%
def plotCompanyTag(companies=["FLOWERS", "force"],tags="Assets"):

    def companyFinder(approxName,df):
        approxName = approxName.lower()
        for i in set(np.array(list(df.index))[:,0]):
            if approxName in i.lower():
                return i
    @np.vectorize
    def timeString2date(x="2020q2"):
        lst = x.split("q")
        num = int(lst[0])+(int(lst[1])-1)*0.25
        labels = f"{x[:5]} {x[:-1]}"
        return num,labels
    
    fig, ax = plt.subplots(1,len(tags))
    
    for i in range(len(tags)):

        all_companies = set(np.array(list(df.index))[:,0])
        for company in companies:
            if company not in all_companies:
                company = companyFinder(company,df)
                y = df.loc[company][tags[i]].values
                #print(df.loc[company][tags[i]].index)
                x,labels = timeString2date(df.loc[company][tags[i]].index)
                #print(x)
                
               
                sort_index = np.argsort(x)

                x = x[sort_index]
                y = y[sort_index]
                print(x)

                ax[i].plot(x,y,label=company)
                ax[i].set_xticklabels(labels)
                ax[i].legend()
                ax[i].set_ylabel(tags[i])

# %%
pre = pd.read_csv("/Users/matthesfogtmann/Downloads/SEC data/2022q3/pre.txt",sep="\t")

# %%
num = pd.read_csv("/Users/matthesfogtmann/Downloads/SEC data/2022q3/num.txt",sep="\t")

# %%
sub = pd.read_csv("/Users/matthesfogtmann/Downloads/SEC data/2022q3/sub.txt",sep="\t")
